# %%
Hay que darle un prompt a la api. Eres un periodista experto en la champions league. Proporciona informacion clara, concisa y estrcuturada sobre el gen 

Vuelve únicaente un JSON con los siguientes campos: goleador, asistente, posesión...

"goleador" : "ej. El maximo goleador de la champions 92-93 fue Koeman que metió un gol en la final"
"asistente" : "ej. Asistencias de Koke en la temporada 2016-2017"

No hay que meter a mano nada, sino hay que preguntarle para que él lo genere.
Al hacer un prompt para que te lo dé de manera más eficiente, hay que hacer un prompt muy preciso, como si fuese un niño pequeño. Muy detallado.

Nunca se sabe cual es el mejor prompt, hay que ir probando. Intentar no hacer faltas y demás porque a lo mejor la API no lo pilla bien.

El prompt que sea lo más fino posible. El punto de dolor es como conseguir ese JSON final para que este muy bien hecho para que cuando pregunte Jacinto me responda todo bien.

# %%
Paso 1:

Recopilar información.

Paso 2: 

Revisar APIs y seleccionar cual vamos a usar.

Paso 3:

Medir mucho los tokens (entre 500-800).

Paso 4:

Con eso embebemos, llamamos a esa API y construimos nuestro fichero final.
